# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

driver = webdriver.Chrome()
driver.get('https://coinmarketcap.com/all/views/all/')
time.sleep(1)


#add parser
page_source = driver.page_source
soup = BeautifulSoup(page_source, 'lxml')

#Next page
driver.execute_script("window.scrollBy(0,500)", "")
driver.execute_script("window.scrollBy(500,1000)", "")

#add scrape info

table = soup.find('table')
rows = table.find_all('tr')

for row in rows:
    symbol = [i.text for i in soup.findAll('td', {'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--left cmc-table__cell--hide-sm cmc-table__cell--sort-by__symbol'})]

    df = pd.DataFrame(symbol)

    
    
print(df)


#symbol = [i.text for i in soup.findAll('td', {'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--left cmc-table__cell--hide-sm cmc-table__cell--sort-by__symbol'})]


#df = pd.DataFrame(symbol)

#df
# Out:
#         0
# 0     BTC
# 1     ETH
# 2     BNB
# 3    USDT
# 4     SOL
# 5     ADA
# 6     XRP
# 7     DOT
# 8    USDC
# 9    DOGE
# 10   AVAX
# 11    CRO
# 12   SHIB
# 13   LUNA
# 14    LTC
# 15   WBTC
# 16    UNI
# 17   BUSD
# 18   LINK
# 19  MATIC

# %%
df
# Out:
#         0
# 0     BTC
# 1     ETH
# 2     BNB
# 3    USDT
# 4     SOL
# 5     ADA
# 6     XRP
# 7     DOT
# 8    USDC
# 9    DOGE
# 10   AVAX
# 11   SHIB
# 12    CRO
# 13   LUNA
# 14    LTC
# 15   WBTC
# 16    UNI
# 17   BUSD
# 18   LINK
# 19  MATIC

# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get('https://coinmarketcap.com/all/views/all/')
time.sleep(1)

#for i in range(1,21):
    #ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    #print(ticker)


#Next page
driver.execute_script("return document.body.scrollHeight")
driver.execute_script("window.scrollTo(0,1175)")

for i in range(23,25):
    ticker2 = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    print(ticker2)



#driver.execute_script("window.scrollTo(0, document.body.scrollHeight")
# Out:
# --------------------------------------------------------------------------
# NoSuchElementException                   Traceback (most recent call last)
# <ipython-input-80-59bd7a1fb889> in <module>
#      19
#      20 for i in range(23,25):
# ---> 21     ticker2 = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
#      22     print(ticker2)
#      23
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr[23]/td[3]/div"}
#   (Session info: chrome=96.0.4664.55)

# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get('https://coinmarketcap.com/all/views/all/')
time.sleep(1)

#for i in range(1,21):
    #ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    #print(ticker)


#Next page
driver.execute_script("return document.body.scrollHeight")
driver.execute_script("window.scrollTo(0,1500)")
#1000 - HNT
#1500 - ONE


for i in range(1,54):
    ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    print(ticker)

#Next page
time.sleep(3)
driver.execute_script("window.scrollTo(1500,3000)")
#2000 - HNT


for i in range(55,65):
    ticker2 = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    print(ticker2)
# Out:
# BTC
# ETH
# BNB
# USDT
# SOL
# ADA
# XRP
# DOT
# USDC
# DOGE
# AVAX
# SHIB
# CRO
# LUNA
# LTC
# WBTC
# UNI
# BUSD
# LINK
# MATIC
# ALGO
# BCH
# EGLD
# VET
# AXS
# XLM
# ICP
# TRX
# MANA
# UST
# ATOM
# FTT
# THETA
# FIL
# DAI
# ETC
# BTCB
# FTM
# HBAR
# NEAR
# SAND
# HNT
# LRC
# XTZ
# XMR
# GRT
# EOS
# FLOW
# MIOTA
# KLAY
# AAVE
# CAKE
# ONE
# --------------------------------------------------------------------------
# NoSuchElementException                   Traceback (most recent call last)
# <ipython-input-125-6961d1e40811> in <module>
#      32
#      33 for i in range(55,65):
# ---> 34     ticker2 = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
#      35     print(ticker2)
#      36
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr[55]/td[3]/div"}
#   (Session info: chrome=96.0.4664.55)

# %%
//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr[1]/td[3]/div
//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr[21]/td[3]/div
