# %%
#Trial 4 - 54 data sets, scroll and scrape method
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get('https://coinmarketcap.com/all/views/all/')
time.sleep(1)

#for i in range(1,21):
    #ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    #print(ticker)


#Next page
driver.execute_script("return document.body.scrollHeight")
driver.execute_script("window.scrollTo(0,1500)")
#1000 - HNT
#1500 - ONE


for i in range(1,54):
    ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    print(ticker)
# Out:
# BTC
# ETH
# BNB
# USDT
# SOL
# ADA
# USDC
# XRP
# DOT
# DOGE
# LUNA
# AVAX
# SHIB
# CRO
# BUSD
# MATIC
# WBTC
# LTC
# UNI
# ALGO
# LINK
# BCH
# TRX
# UST
# XLM
# AXS
# DAI
# MANA
# FTT
# VET
# ATOM
# EGLD
# ICP
# FIL
# BTCB
# ETC
# THETA
# SAND
# HBAR
# NEAR
# FTM
# XMR
# XTZ
# GRT
# MIOTA
# KLAY
# LEO
# GALA
# HNT
# FLOW
# EOS
# CAKE
# STX

# %%
#Trial 5 - 65 data sets, scroll and scrape method
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get('https://coinmarketcap.com/all/views/all/')
time.sleep(1)

#for i in range(1,21):
    #ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    #print(ticker)


#Next page
driver.execute_script("window.scrollTo(0,1500)")
#1000 - HNT
#1500 - ONE


for i in range(1,54):
    ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    print(ticker)
#Next page
time.sleep(3)
driver.execute_script("window.scrollTo(1500,3000)")
#2000 - HNT


for i in range(55,65):
    ticker2 = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    print(ticker2)
    
#note to Julia, I can only run this successfully once on the first call, I don't know why each subsequent call will break.
# Out:
# BTC
# ETH
# BNB
# USDT
# SOL
# ADA
# XRP
# DOT
# USDC
# DOGE
# AVAX
# SHIB
# CRO
# LUNA
# LTC
# WBTC
# UNI
# BUSD
# LINK
# MATIC
# ALGO
# BCH
# EGLD
# AXS
# XLM
# VET
# MANA
# ICP
# UST
# TRX
# FTT
# ATOM
# THETA
# DAI
# FIL
# ETC
# BTCB
# FTM
# NEAR
# HBAR
# SAND
# HNT
# XTZ
# XMR
# LRC
# GRT
# EOS
# FLOW
# MIOTA
# KLAY
# CAKE
# AAVE
# ONE
# ZEC
# LEO
# XEC
# MKR
# GALA
# BSV
# KSM
# NEO
# RUNE
# QNT

# %%
#Trial 6 - using while method to scroll all the way down, failed, stuck on forever while loop
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get('https://coinmarketcap.com/all/views/all/')
time.sleep(1)

#for i in range(1,21):
    #ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    #print(ticker)


#Next page
#driver.execute_script("window.scrollTo(0,1500)")
#1000 - HNT
#1500 - ONE




driver.execute_script('return document.body.scrollHeight')

#while True:
    #driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')


for i in range(1,19):
    ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    print(ticker)
# Out:
# BTC
# ETH
# BNB
# USDT
# SOL
# ADA
# USDC
# XRP
# DOT
# DOGE
# LUNA
# AVAX
# SHIB
# CRO
# BUSD
# MATIC
# WBTC
# LTC

# %%
#Trial 7 - Load x4 times, Manually scroll through entirely to bottom, then scrape, WORKED!!!!!
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get('https://coinmarketcap.com/all/views/all/')
time.sleep(1)

#for i in range(1,21):
    #ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    #print(ticker)

#1000 - HNT
#1500 - ONE
#2000 - HNT

#Next page
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
load_more = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[3]/button').click()
time.sleep(3)
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
load_more = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[3]/button').click()
time.sleep(3)
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
load_more = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[3]/button').click()
time.sleep(3)
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
load_more = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[3]/button').click()
time.sleep(3)

#driver.execute_script('return document.body.scrollHeight')

driver.execute_script("window.scrollTo(0,1500)")
time.sleep(1)
driver.execute_script("window.scrollTo(1500,3000)")
time.sleep(1)
driver.execute_script("window.scrollTo(3000,4500)")
time.sleep(1)
driver.execute_script("window.scrollTo(4500,6000)")
time.sleep(1)
driver.execute_script("window.scrollTo(6000,7500)")
time.sleep(1)
driver.execute_script("window.scrollTo(7500,9000)")
time.sleep(1)
driver.execute_script("window.scrollTo(9000,10500)")
time.sleep(1)
driver.execute_script("window.scrollTo(10500,12000)")
time.sleep(1)
driver.execute_script("window.scrollTo(12000,13500)")
time.sleep(1)
driver.execute_script("window.scrollTo(13500,15000)")
time.sleep(1)
driver.execute_script("window.scrollTo(15000,16500)")
time.sleep(1)
driver.execute_script("window.scrollTo(16500,18000)")
time.sleep(1)
driver.execute_script("window.scrollTo(18000,19500)")
time.sleep(1)
driver.execute_script("window.scrollTo(19500,21000)")
time.sleep(1)
driver.execute_script("window.scrollTo(21000,22500)")
time.sleep(1)
driver.execute_script("window.scrollTo(22500,24000)")
time.sleep(1)
driver.execute_script("window.scrollTo(24000,25500)")
time.sleep(1)
driver.execute_script("window.scrollTo(25500,27000)")
time.sleep(1)
driver.execute_script("window.scrollTo(27000,28500)")
time.sleep(1)
driver.execute_script("window.scrollTo(28500,30000)")
time.sleep(1)
driver.execute_script("window.scrollTo(30000,31500)")
time.sleep(1)
driver.execute_script("window.scrollTo(31500,33000)")
time.sleep(1)
driver.execute_script("window.scrollTo(33000,34500)")
time.sleep(1)
driver.execute_script("window.scrollTo(34500,36000)")
time.sleep(1)
driver.execute_script("window.scrollTo(36000,37500)")
time.sleep(1)
driver.execute_script("window.scrollTo(37500,39000)")
time.sleep(1)
driver.execute_script("window.scrollTo(39000,40500)")
time.sleep(1)
driver.execute_script("window.scrollTo(40500,42000)")
time.sleep(1)
driver.execute_script("window.scrollTo(42000,43500)")
time.sleep(1)
driver.execute_script("window.scrollTo(43500,45000)")
time.sleep(1)
driver.execute_script("window.scrollTo(45000,45253)")

symbol = []
market_cap = []
price = []
circulation = []
volume = []
one_hour = []
twenty_four = []
seven_day = []

for i in range(1, 1001):
    ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    symbol.append(ticker)
    marketCap = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[4]/p/span[2]').text;
    market_cap.append(marketCap)
    price_= driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[5]/div/a/span').text;
    price.append(price_)
    circulation_ = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[6]/div').text;
    circulation.append(circulation_)
    volume_ = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[7]/a').text;
    volume.append(volume_)
    oneHour = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[8]/div').text;
    one_hour.append(oneHour)
    twentyFourHours = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[9]/div').text;
    twenty_four.append(twentyFourHours)
    sevenDays = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[10]/div').text;
    seven_day.append(sevenDays)

# %%
#total page lenght is 45253

#test the last dataset to see if above scraping was successful
seven_day
# Out:
# ['-14.28%',
#  '-4.99%',
#  '-10.13%',
#  '-0.07%',
#  '-3.36%',
#  '-12.96%',
#  '-0.05%',
#  '-18.61%',
#  '-21.12%',
#  '-20.80%',
#  '26.90%',
#  '-18.97%',
#  '-8.32%',
#  '-30.02%',
#  '-0.15%',
#  '8.99%',
#  '-13.37%',
#  '-22.18%',
#  '-17.15%',
#  '-9.73%',
#  '-21.33%',
#  '-20.05%',
#  '-11.94%',
#  '-0.33%',
#  '-14.70%',
#  '-14.51%',
#  '-0.26%',
#  '-28.07%',
#  '-11.76%',
#  '-22.56%',
#  '-7.26%',
#  '-30.02%',
#  '-35.11%',
#  '-32.00%',
#  '-14.26%',
#  '-29.12%',
#  '-23.17%',
#  '-20.51%',
#  '-24.11%',
#  '-9.08%',
#  '-28.22%',
#  '-13.02%',
#  '-14.66%',
#  '-33.30%',
#  '-17.41%',
#  '-11.25%',
#  '2.80%',
#  '-28.02%',
#  '-35.96%',
#  '-22.27%',
#  '-23.75%',
#  '-17.60%',
#  '9.20%',
#  '-34.53%',
#  '-20.42%',
#  '-12.70%',
#  '-21.10%',
#  '-23.23%',
#  '-16.67%',
#  '-34.44%',
#  '-30.66%',
#  '-24.66%',
#  '-31.25%',
#  '-14.96%',
#  '-32.91%',
#  '-27.97%',
#  '-26.60%',
#  '-23.72%',
#  '-31.16%',
#  '-13.84%',
#  '-7.75%',
#  '-37.13%',
# ...

# %%
#Combining all dataFrames
df1 = pd.DataFrame(symbol)
df2 = pd.DataFrame(market_cap)
df3 = pd.DataFrame(price)
df4 = pd.DataFrame(circulation) 
df5 = pd.DataFrame(volume) 
df6 = pd.DataFrame(one_hour) 
df7 = pd.DataFrame(twenty_four)
df8 = pd.DataFrame(seven_day)

stack = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8], axis = 1)
stack
# Out:
#         0                 0           0                      0  \
# 0     BTC  $892,706,148,682  $47,255.66         18,890,987 BTC
# 1     ETH  $468,360,483,757   $3,949.01        118,602,065 ETH
# 2     BNB   $91,421,738,945     $548.09      166,801,148 BNB *
# 3    USDT   $74,171,898,404       $1.00  74,157,654,134 USDT *
# 4     SOL   $58,794,228,840     $192.36      305,641,219 SOL *
# ..    ...               ...         ...                    ...
# 995  PING       $14,072,176   $0.005205   2,703,464,935 PING *
# 996   BIN       $14,044,630    $0.01756      800,000,000 BIN *
# 997  FEAR       $13,990,611       $2.14       6,532,157 FEAR *
# 998  AGRS       $13,984,296     $0.7769      18,000,000 AGRS *
# 999  BETU       $13,925,667     $0.1294     107,608,038 BETU *
#
#                     0       0        0        0
# 0     $62,790,500,867  -0.14%  -17.73%  -14.28%
# 1     $41,456,635,706   0.27%  -15.01%   -4.99%
# 2      $4,576,646,205   0.21%  -12.38%  -10.13%
# ...

# %%
#adding headers
stack = stack.drop('try',1)
stack.columns = ['Symbol', 'Market Cap', 'Price', 'Circulating Supply', 'Volume(24h)', '% 1h', '% 24h', '% 7d']

stack
# Out:
#     Symbol        Market Cap       Price     Circulating Supply  \
# 0      BTC  $892,706,148,682  $47,255.66         18,890,987 BTC
# 1      ETH  $468,360,483,757   $3,949.01        118,602,065 ETH
# 2      BNB   $91,421,738,945     $548.09      166,801,148 BNB *
# 3     USDT   $74,171,898,404       $1.00  74,157,654,134 USDT *
# 4      SOL   $58,794,228,840     $192.36      305,641,219 SOL *
# ..     ...               ...         ...                    ...
# 995   PING       $14,072,176   $0.005205   2,703,464,935 PING *
# 996    BIN       $14,044,630    $0.01756      800,000,000 BIN *
# 997   FEAR       $13,990,611       $2.14       6,532,157 FEAR *
# 998   AGRS       $13,984,296     $0.7769      18,000,000 AGRS *
# 999   BETU       $13,925,667     $0.1294     107,608,038 BETU *
#
#           Volume(24h)    % 1h    % 24h     % 7d
# 0     $62,790,500,867 -0.0014  -17.73%  -14.28%
# 1     $41,456,635,706  0.0027  -15.01%   -4.99%
# 2      $4,576,646,205  0.0021  -12.38%  -10.13%
# ...

# %%
#Cleaning 1hr column

stack["% 1h"] = stack['% 1h'].map(lambda x: x.rstrip('%'))
stack["% 1h"] = pd.to_numeric(stack["% 1h"], downcast='float')
stack.dtypes
# Out:
# Symbol                 object
# Market Cap             object
# Price                  object
# Circulating Supply     object
# Volume(24h)            object
# % 1h                  float32
# % 24h                  object
# % 7                    object
# try                    object
# dtype: object

# %%
stack
# Out:
#     Symbol        Market Cap       Price     Circulating Supply  \
# 0      BTC  $892,706,148,682  $47,255.66         18,890,987 BTC
# 1      ETH  $468,360,483,757   $3,949.01        118,602,065 ETH
# 2      BNB   $91,421,738,945     $548.09      166,801,148 BNB *
# 3     USDT   $74,171,898,404       $1.00  74,157,654,134 USDT *
# 4      SOL   $58,794,228,840     $192.36      305,641,219 SOL *
# ..     ...               ...         ...                    ...
# 995   PING       $14,072,176   $0.005205   2,703,464,935 PING *
# 996    BIN       $14,044,630    $0.01756      800,000,000 BIN *
# 997   FEAR       $13,990,611       $2.14       6,532,157 FEAR *
# 998   AGRS       $13,984,296     $0.7769      18,000,000 AGRS *
# 999   BETU       $13,925,667     $0.1294     107,608,038 BETU *
#
#           Volume(24h)  % 1h    % 24h      % 7    try
# 0     $62,790,500,867 -0.14  -17.73%  -14.28%  -0.14
# 1     $41,456,635,706  0.27  -15.01%   -4.99%   0.27
# ...

# %%
stack['% 1h'] = stack['% 1h'].div(100)
stack
# Out:
#     Symbol        Market Cap       Price     Circulating Supply  \
# 0      BTC  $892,706,148,682  $47,255.66         18,890,987 BTC
# 1      ETH  $468,360,483,757   $3,949.01        118,602,065 ETH
# 2      BNB   $91,421,738,945     $548.09      166,801,148 BNB *
# 3     USDT   $74,171,898,404       $1.00  74,157,654,134 USDT *
# 4      SOL   $58,794,228,840     $192.36      305,641,219 SOL *
# ..     ...               ...         ...                    ...
# 995   PING       $14,072,176   $0.005205   2,703,464,935 PING *
# 996    BIN       $14,044,630    $0.01756      800,000,000 BIN *
# 997   FEAR       $13,990,611       $2.14       6,532,157 FEAR *
# 998   AGRS       $13,984,296     $0.7769      18,000,000 AGRS *
# 999   BETU       $13,925,667     $0.1294     107,608,038 BETU *
#
#           Volume(24h)    % 1h    % 24h      % 7    try
# 0     $62,790,500,867 -0.0014  -17.73%  -14.28%  -0.14
# 1     $41,456,635,706  0.0027  -15.01%   -4.99%   0.27
# ...

# %%
#Cleaning 24h and 7d columns

stack["% 24h"] = stack['% 24h'].map(lambda x: x.rstrip('%'))
stack["% 24h"] = pd.to_numeric(stack["% 24h"], downcast='float')

stack["% 7d"] = stack['% 7d'].map(lambda x: x.rstrip('%'))
stack["% 7d"] = pd.to_numeric(stack["% 7d"], downcast='float')

stack.dtypes
# Out:
# Symbol                 object
# Market Cap             object
# Price                  object
# Circulating Supply     object
# Volume(24h)            object
# % 1h                  float32
# % 24h                 float32
# % 7d                  float32
# dtype: object

# %%
stack
# Out:
#     Symbol        Market Cap       Price     Circulating Supply  \
# 0      BTC  $892,706,148,682  $47,255.66         18,890,987 BTC
# 1      ETH  $468,360,483,757   $3,949.01        118,602,065 ETH
# 2      BNB   $91,421,738,945     $548.09      166,801,148 BNB *
# 3     USDT   $74,171,898,404       $1.00  74,157,654,134 USDT *
# 4      SOL   $58,794,228,840     $192.36      305,641,219 SOL *
# ..     ...               ...         ...                    ...
# 995   PING       $14,072,176   $0.005205   2,703,464,935 PING *
# 996    BIN       $14,044,630    $0.01756      800,000,000 BIN *
# 997   FEAR       $13,990,611       $2.14       6,532,157 FEAR *
# 998   AGRS       $13,984,296     $0.7769      18,000,000 AGRS *
# 999   BETU       $13,925,667     $0.1294     107,608,038 BETU *
#
#           Volume(24h)    % 1h      % 24h   % 7d
# 0     $62,790,500,867 -0.0014 -17.730000 -14.28
# 1     $41,456,635,706  0.0027 -15.010000  -4.99
# 2      $4,576,646,205  0.0021 -12.380000 -10.13
# ...

# %%
stack['% 24h'] = stack['% 24h'].div(100)
stack['% 7d'] = stack['% 7d'].div(100)

stack
# Out:
#     Symbol        Market Cap       Price     Circulating Supply  \
# 0      BTC  $892,706,148,682  $47,255.66         18,890,987 BTC
# 1      ETH  $468,360,483,757   $3,949.01        118,602,065 ETH
# 2      BNB   $91,421,738,945     $548.09      166,801,148 BNB *
# 3     USDT   $74,171,898,404       $1.00  74,157,654,134 USDT *
# 4      SOL   $58,794,228,840     $192.36      305,641,219 SOL *
# ..     ...               ...         ...                    ...
# 995   PING       $14,072,176   $0.005205   2,703,464,935 PING *
# 996    BIN       $14,044,630    $0.01756      800,000,000 BIN *
# 997   FEAR       $13,990,611       $2.14       6,532,157 FEAR *
# 998   AGRS       $13,984,296     $0.7769      18,000,000 AGRS *
# 999   BETU       $13,925,667     $0.1294     107,608,038 BETU *
#
#           Volume(24h)    % 1h   % 24h    % 7d
# 0     $62,790,500,867 -0.0014 -0.1773 -0.1428
# 1     $41,456,635,706  0.0027 -0.1501 -0.0499
# 2      $4,576,646,205  0.0021 -0.1238 -0.1013
# ...

# %%
#cleaning Marketcap, Price, and Volume Columns

#stack['Volume(24h)'] = stack['Volume(24h)'].map(lambda x: x.lstrip(',').rstrip(','))
#stack['Volume(24h)'] = stack['Volume(24h)'].str.replace("?", '')
stack['Volume(24h)'] = pd.to_numeric(stack["Volume(24h)"], downcast='float')



stack
# Out:
#     Symbol        Market Cap       Price     Circulating Supply   Volume(24h)  \
# 0      BTC  $892,706,148,682  $47,255.66         18,890,987 BTC  6.279050e+10
# 1      ETH  $468,360,483,757   $3,949.01        118,602,065 ETH  4.145664e+10
# 2      BNB   $91,421,738,945     $548.09      166,801,148 BNB *  4.576646e+09
# 3     USDT   $74,171,898,404       $1.00  74,157,654,134 USDT *  1.442001e+11
# 4      SOL   $58,794,228,840     $192.36      305,641,219 SOL *  6.513758e+09
# ..     ...               ...         ...                    ...           ...
# 995   PING       $14,072,176   $0.005205   2,703,464,935 PING *  5.515740e+05
# 996    BIN       $14,044,630    $0.01756      800,000,000 BIN *  1.962260e+06
# 997   FEAR       $13,990,611       $2.14       6,532,157 FEAR *  1.343316e+07
# 998   AGRS       $13,984,296     $0.7769      18,000,000 AGRS *  5.813000e+03
# 999   BETU       $13,925,667     $0.1294     107,608,038 BETU *  8.872450e+05
#
#        % 1h   % 24h    % 7d
# ...

# %%
#stack['Price'] = stack['Price'].str.replace('$', '').str.replace(",", '')
stack['Price'] = pd.to_numeric(stack["Price"], downcast='float')

stack
# Out:
#     Symbol        Market Cap         Price     Circulating Supply  \
# 0      BTC  $892,706,148,682  47255.660156         18,890,987 BTC
# 1      ETH  $468,360,483,757   3949.010010        118,602,065 ETH
# 2      BNB   $91,421,738,945    548.090027      166,801,148 BNB *
# 3     USDT   $74,171,898,404      1.000000  74,157,654,134 USDT *
# 4      SOL   $58,794,228,840    192.360001      305,641,219 SOL *
# ..     ...               ...           ...                    ...
# 995   PING       $14,072,176      0.005205   2,703,464,935 PING *
# 996    BIN       $14,044,630      0.017560      800,000,000 BIN *
# 997   FEAR       $13,990,611      2.140000       6,532,157 FEAR *
# 998   AGRS       $13,984,296      0.776900      18,000,000 AGRS *
# 999   BETU       $13,925,667      0.129400     107,608,038 BETU *
#
#       Volume(24h)    % 1h   % 24h    % 7d
# 0    6.279050e+10 -0.0014 -0.1773 -0.1428
# 1    4.145664e+10  0.0027 -0.1501 -0.0499
# 2    4.576646e+09  0.0021 -0.1238 -0.1013
# ...

# %%
#stack['Market Cap'] = stack['Market Cap'].str.replace('$', '').str.replace(",", '')
stack['Market Cap'] = pd.to_numeric(stack["Market Cap"], downcast='float')

stack
# Out:
#     Symbol    Market Cap         Price     Circulating Supply   Volume(24h)  \
# 0      BTC  8.927062e+11  47255.660156         18,890,987 BTC  6.279050e+10
# 1      ETH  4.683605e+11   3949.010010        118,602,065 ETH  4.145664e+10
# 2      BNB  9.142174e+10    548.090027      166,801,148 BNB *  4.576646e+09
# 3     USDT  7.417190e+10      1.000000  74,157,654,134 USDT *  1.442001e+11
# 4      SOL  5.879423e+10    192.360001      305,641,219 SOL *  6.513758e+09
# ..     ...           ...           ...                    ...           ...
# 995   PING  1.407218e+07      0.005205   2,703,464,935 PING *  5.515740e+05
# 996    BIN  1.404463e+07      0.017560      800,000,000 BIN *  1.962260e+06
# 997   FEAR  1.399061e+07      2.140000       6,532,157 FEAR *  1.343316e+07
# 998   AGRS  1.398430e+07      0.776900      18,000,000 AGRS *  5.813000e+03
# 999   BETU  1.392567e+07      0.129400     107,608,038 BETU *  8.872450e+05
#
#        % 1h   % 24h    % 7d
# ...

# %%
stack['Circulating Supply'] = stack['Circulating Supply'].str.split(' ', n = 1, expand=True)
stack
# Out:
#     Symbol    Market Cap         Price Circulating Supply   Volume(24h)  \
# 0      BTC  8.927062e+11  47255.660156         18,890,987  6.279050e+10
# 1      ETH  4.683605e+11   3949.010010        118,602,065  4.145664e+10
# 2      BNB  9.142174e+10    548.090027        166,801,148  4.576646e+09
# 3     USDT  7.417190e+10      1.000000     74,157,654,134  1.442001e+11
# 4      SOL  5.879423e+10    192.360001        305,641,219  6.513758e+09
# ..     ...           ...           ...                ...           ...
# 995   PING  1.407218e+07      0.005205      2,703,464,935  5.515740e+05
# 996    BIN  1.404463e+07      0.017560        800,000,000  1.962260e+06
# 997   FEAR  1.399061e+07      2.140000          6,532,157  1.343316e+07
# 998   AGRS  1.398430e+07      0.776900         18,000,000  5.813000e+03
# 999   BETU  1.392567e+07      0.129400        107,608,038  8.872450e+05
#
#        % 1h   % 24h    % 7d
# 0   -0.0014 -0.1773 -0.1428
# 1    0.0027 -0.1501 -0.0499
# ...

# %%
#stack['Circulating Supply'] = stack['Circulating Supply'].str.replace(",", '')
stack['Circulating Supply'] = pd.to_numeric(stack["Circulating Supply"], downcast='float')

stack
# Out:
#     Symbol    Market Cap         Price  Circulating Supply   Volume(24h)  \
# 0      BTC  8.927062e+11  47255.660156        1.889099e+07  6.279050e+10
# 1      ETH  4.683605e+11   3949.010010        1.186021e+08  4.145664e+10
# 2      BNB  9.142174e+10    548.090027        1.668012e+08  4.576646e+09
# 3     USDT  7.417190e+10      1.000000        7.415765e+10  1.442001e+11
# 4      SOL  5.879423e+10    192.360001        3.056412e+08  6.513758e+09
# ..     ...           ...           ...                 ...           ...
# 995   PING  1.407218e+07      0.005205        2.703465e+09  5.515740e+05
# 996    BIN  1.404463e+07      0.017560        8.000000e+08  1.962260e+06
# 997   FEAR  1.399061e+07      2.140000        6.532157e+06  1.343316e+07
# 998   AGRS  1.398430e+07      0.776900        1.800000e+07  5.813000e+03
# 999   BETU  1.392567e+07      0.129400        1.076080e+08  8.872450e+05
#
#        % 1h   % 24h    % 7d
# 0   -0.0014 -0.1773 -0.1428
# 1    0.0027 -0.1501 -0.0499
# ...

# %%
stack.dtypes
#data is not clean
# Out:
# Symbol                 object
# Market Cap            float32
# Price                 float32
# Circulating Supply    float32
# Volume(24h)           float32
# % 1h                  float32
# % 24h                 float32
# % 7d                  float32
# dtype: object

# %%
import statsmodels.api as sm
#Analysis
x = stack.drop(columns = ['Price'])
x = sm.add_constant(x)
y = stack['Price']

model = sm.OLS(y, x data = stack)
crypto_model = model.fit()
crypto_model.summary()

# %%
import pandas as pd
df = pd.read_csv("Data_Crypto2.csv")
df
# Out:
#     Symbol    Market Cap         Price  Circulating Supply   Volume(24h)  \
# 0      BTC  8.927062e+11  47255.660000        1.889099e+07  6.279050e+10
# 1      ETH  4.683605e+11   3949.010000        1.186021e+08  4.145664e+10
# 2      BNB  9.142174e+10    548.090000        1.668012e+08  4.576646e+09
# 3     USDT  7.417190e+10      1.000000        7.415765e+10  1.442001e+11
# 4      SOL  5.879423e+10    192.360000        3.056412e+08  6.513758e+09
# ..     ...           ...           ...                 ...           ...
# 995   PING  1.407218e+07      0.005205        2.703465e+09  5.515740e+05
# 996    BIN  1.404463e+07      0.017560        8.000000e+08  1.962260e+06
# 997   FEAR  1.399061e+07      2.140000        6.532157e+06  1.343316e+07
# 998   AGRS  1.398430e+07      0.776900        1.800000e+07  5.813000e+03
# 999   BETU  1.392567e+07      0.129400        1.076080e+08  8.872450e+05
#
#        % 1h   % 24h    % 7d
# 0   -0.0014 -0.1773 -0.1428
# 1    0.0027 -0.1501 -0.0499
# ...

# %%
import statsmodels.api as sm
#Analysis
x = df.drop(columns = ['Price', 'Symbol'])
x = sm.add_constant(x)
y = df['Price']

model = sm.OLS(y, x, data = df)
crypto_model = model.fit()
crypto_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.079
# Model:                            OLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     21.37
# Date:                Sun, 12 Dec 2021   Prob (F-statistic):           6.32e-17
# Time:                        10:51:07   Log-Likelihood:                -9871.4
# No. Observations:                1000   AIC:                         1.975e+04
# Df Residuals:                     995   BIC:                         1.978e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
#df = df.drop('Delete',1)
#df
# Out:
#     Symbol    Market Cap         Price  Circulating Supply   Volume(24h)  \
# 0      BTC  8.927062e+11  47255.660000        1.889099e+07  6.279050e+10
# 1      ETH  4.683605e+11   3949.010000        1.186021e+08  4.145664e+10
# 2      BNB  9.142174e+10    548.090000        1.668012e+08  4.576646e+09
# 3     USDT  7.417190e+10      1.000000        7.415765e+10  1.442001e+11
# 4      SOL  5.879423e+10    192.360000        3.056412e+08  6.513758e+09
# ..     ...           ...           ...                 ...           ...
# 995   PING  1.407218e+07      0.005205        2.703465e+09  5.515740e+05
# 996    BIN  1.404463e+07      0.017560        8.000000e+08  1.962260e+06
# 997   FEAR  1.399061e+07      2.140000        6.532157e+06  1.343316e+07
# 998   AGRS  1.398430e+07      0.776900        1.800000e+07  5.813000e+03
# 999   BETU  1.392567e+07      0.129400        1.076080e+08  8.872450e+05
#
#        % 1h   % 24h    % 7d
# 0   -0.0014 -0.1773 -0.1428
# 1    0.0027 -0.1501 -0.0499
# ...

# %%
import statsmodels.api as sm
#Analysis
x = df.drop(columns = ['Price', 'Symbol'])
x = sm.add_constant(x)
y = df['Price']
z = df[['Circulating Supply', '% 1h']]

#model = sm.OLS(y, x, data = df)
#crypto_model = model.fit()
#crypto_model.summary()
z.head()
# Out:
#    Circulating Supply    % 1h
# 0        1.889099e+07 -0.0014
# 1        1.186021e+08  0.0027
# 2        1.668012e+08  0.0021
# 3        7.415765e+10 -0.0001
# 4        3.056412e+08  0.0001

# %%
import statsmodels.api as sm

# %%
import seaborn as sns
sns.pairplot(z)

# %%
df

# %%
sns.pairplot(x)

# %%
df['Volume(24h)'].fillna(100, inplace=True)

# %%
df
# Out:
#     Symbol    Market Cap         Price  Circulating Supply   Volume(24h)  \
# 0      BTC  8.927062e+11  47255.660000        1.889099e+07  6.279050e+10
# 1      ETH  4.683605e+11   3949.010000        1.186021e+08  4.145664e+10
# 2      BNB  9.142174e+10    548.090000        1.668012e+08  4.576646e+09
# 3     USDT  7.417190e+10      1.000000        7.415765e+10  1.442001e+11
# 4      SOL  5.879423e+10    192.360000        3.056412e+08  6.513758e+09
# ..     ...           ...           ...                 ...           ...
# 995   PING  1.407218e+07      0.005205        2.703465e+09  5.515740e+05
# 996    BIN  1.404463e+07      0.017560        8.000000e+08  1.962260e+06
# 997   FEAR  1.399061e+07      2.140000        6.532157e+06  1.343316e+07
# 998   AGRS  1.398430e+07      0.776900        1.800000e+07  5.813000e+03
# 999   BETU  1.392567e+07      0.129400        1.076080e+08  8.872450e+05
#
#        % 1h   % 24h    % 7d
# 0   -0.0014 -0.1773 -0.1428
# 1    0.0027 -0.1501 -0.0499
# ...

# %%
df.to_csv('Data_Crypto2.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a374c05c8b34> in <module>
# ----> 1 df.to_csv('Data_Crypto2.csv', index=False)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read_csv("Data_Crypto2.csv")
df
# Out:
#     Symbol    Market Cap         Price  Circulating Supply   Volume(24h)  \
# 0      BTC  8.927062e+11  47255.660000        1.889099e+07  6.279050e+10
# 1      ETH  4.683605e+11   3949.010000        1.186021e+08  4.145664e+10
# 2      BNB  9.142174e+10    548.090000        1.668012e+08  4.576646e+09
# 3     USDT  7.417190e+10      1.000000        7.415765e+10  1.442001e+11
# 4      SOL  5.879423e+10    192.360000        3.056412e+08  6.513758e+09
# ..     ...           ...           ...                 ...           ...
# 995   PING  1.407218e+07      0.005205        2.703465e+09  5.515740e+05
# 996    BIN  1.404463e+07      0.017560        8.000000e+08  1.962260e+06
# 997   FEAR  1.399061e+07      2.140000        6.532157e+06  1.343316e+07
# 998   AGRS  1.398430e+07      0.776900        1.800000e+07  5.813000e+03
# 999   BETU  1.392567e+07      0.129400        1.076080e+08  8.872450e+05
#
#        % 1h   % 24h    % 7d
# 0   -0.0014 -0.1773 -0.1428
# 1    0.0027 -0.1501 -0.0499
# ...

# %%
import statsmodels.api as sm
#Analysis
x = df.drop(columns = ['Price', 'Symbol', 'Market Cap'])
x = sm.add_constant(x)
y = df['Price']
z = df[['Price', '% 1h', '% 24h', '% 7d']]
z2 = df[['Price', 'Market Cap']]
z3 = df[['Price', 'Volume(24h)']]
z4 = df[['Price', 'Circulating Supply']]

model = sm.OLS(y, x, data = df)
crypto_model = model.fit()
crypto_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     4.708
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):            0.00286
# Time:                        07:10:33   Log-Likelihood:                -9905.6
# No. Observations:                1000   AIC:                         1.982e+04
# Df Residuals:                     996   BIC:                         1.984e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
z.head()
# Out:
#       Price    % 1h   % 24h    % 7d
# 0  47255.66 -0.0014 -0.1773 -0.1428
# 1   3949.01  0.0027 -0.1501 -0.0499
# 2    548.09  0.0021 -0.1238 -0.1013
# 3      1.00 -0.0001 -0.0009 -0.0007
# 4    192.36  0.0001 -0.1955 -0.0336

# %%
import seaborn as sns
sns.pairplot(z)
z.dtypes()

# %%
import seaborn as sns
sns.pairplot(z2)

# %%
import seaborn as sns
sns.pairplot(z3)

# %%
sns.pairplot(z4)

# %%
df.describe()
# Out:
#          Market Cap         Price  Circulating Supply   Volume(24h)  \
# count  1.000000e+03  1.000000e+03        1.000000e+03  1.000000e+03
# mean   2.320889e+09  5.086683e+02        6.978904e+12  4.055894e+08
# std    3.224674e+10  4.886140e+03        9.301936e+13  5.184770e+09
# min    1.392567e+07  1.361000e-08        3.020000e+02  9.000000e+00
# 25%    2.839835e+07  1.058750e-01        3.046553e+07  1.270787e+06
# 50%    8.303034e+07  7.303500e-01        1.498556e+08  6.785213e+06
# 75%    2.733084e+08  4.180000e+00        9.992192e+08  4.933795e+07
# max    8.927062e+11  9.098211e+04        2.384230e+15  1.442001e+11
#
#               % 1h        % 24h         % 7d
# count  1000.000000  1000.000000  1000.000000
# mean     -0.000101    -0.178689    -0.144834
# std       0.021805     0.106516     0.271227
# min      -0.099000    -0.465200    -0.898200
# 25%      -0.006600    -0.242225    -0.266525
# 50%      -0.001250    -0.192100    -0.178650
# ...

# %%
df.dtypes
# Out:
# Symbol                 object
# Market Cap            float64
# Price                 float64
# Circulating Supply    float64
# Volume(24h)           float64
# % 1h                  float64
# % 24h                 float64
# % 7d                  float64
# dtype: object

# %%
a = df.drop(columns = ['Circulating Supply', 'Symbol'])

# %%
sns.pairplot(df, diag_kind='kde')

# %%
df.Price.value_counts()
# Out:
# 1.000000       5
# 1.130000       3
# 1.040000       3
# 2.930000       3
# 1.400000       3
#               ..
# 1292.760000    1
# 0.157200       1
# 0.000613       1
# 0.010330       1
# 1.970000       1
# Name: Price, Length: 932, dtype: int64

# %%
#log transformation on all variables
df['Market Cap'].value_counts()
# Out:
# 2.316492e+07    1
# 1.544313e+08    1
# 4.006460e+07    1
# 5.821508e+08    1
# 6.744192e+09    1
#                ..
# 4.615702e+07    1
# 3.152932e+08    1
# 1.572894e+07    1
# 3.914883e+07    1
# 5.516343e+08    1
# Name: Market Cap, Length: 1000, dtype: int64

# %%
import numpy as np
log_y = np.log(y)
log_x = np.log(x)
log_model = sm.OLS(log_y, x)
log_fit = log_model.fit()
log_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.112
# Model:                            OLS   Adj. R-squared:                  0.109
# Method:                 Least Squares   F-statistic:                     41.81
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):           1.89e-25
# Time:                        07:11:07   Log-Likelihood:                -2628.7
# No. Observations:                1000   AIC:                             5265.
# Df Residuals:                     996   BIC:                             5285.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
df
# Out:
#     Symbol    Market Cap         Price  Circulating Supply   Volume(24h)  \
# 0      BTC  8.927062e+11  47255.660000        1.889099e+07  6.279050e+10
# 1      ETH  4.683605e+11   3949.010000        1.186021e+08  4.145664e+10
# 2      BNB  9.142174e+10    548.090000        1.668012e+08  4.576646e+09
# 3     USDT  7.417190e+10      1.000000        7.415765e+10  1.442001e+11
# 4      SOL  5.879423e+10    192.360000        3.056412e+08  6.513758e+09
# ..     ...           ...           ...                 ...           ...
# 995   PING  1.407218e+07      0.005205        2.703465e+09  5.515740e+05
# 996    BIN  1.404463e+07      0.017560        8.000000e+08  1.962260e+06
# 997   FEAR  1.399061e+07      2.140000        6.532157e+06  1.343316e+07
# 998   AGRS  1.398430e+07      0.776900        1.800000e+07  5.813000e+03
# 999   BETU  1.392567e+07      0.129400        1.076080e+08  8.872450e+05
#
#        % 1h   % 24h    % 7d
# 0   -0.0014 -0.1773 -0.1428
# 1    0.0027 -0.1501 -0.0499
# ...

# %%
df_log = df.apply(lambda x: np.log(x) if x.name in ["Price", "Market Cap", 'Circulating Supply', 'Volume(24h)'] else x)

#df_log2 = df_log.drop('Market Cap', axis = 1)
df_log
# Out:
#     Symbol  Market Cap      Price  Circulating Supply  Volume(24h)    % 1h  \
# 0      BTC   27.517523  10.763328           16.754196    24.863070 -0.0014
# 1      ETH   26.872504   8.281220           18.591284    24.447914  0.0027
# 2      BNB   25.238749   6.306440           18.932313    22.244232  0.0021
# 3     USDT   25.029651   0.000000           25.029459    25.694468 -0.0001
# 4      SOL   24.797310   5.259369           19.537922    22.597182  0.0001
# ..     ...         ...        ...                 ...          ...     ...
# 995   PING   16.459710  -5.258136           21.717800    13.220531 -0.0063
# 996    BIN   16.457751  -4.042132           20.500122    14.489607  0.0132
# 997   FEAR   16.453897   0.760806           15.692248    16.413237 -0.0054
# 998   AGRS   16.453446  -0.252444           16.705882     8.667852  0.0371
# 999   BETU   16.449244  -2.044847           18.494006    13.695876  0.0034
#
#       % 24h    % 7d
# 0   -0.1773 -0.1428
# 1   -0.1501 -0.0499
# ...

# %%
import seaborn as sns
sns.pairplot(df_log, diag_kind='kde')

# %%
df['Circulating Supply'].value_counts()
# Out:
# 1.000000e+09    7
# 1.500000e+08    3
# 1.000000e+10    3
# 1.000000e+08    2
# 2.493477e+08    2
#                ..
# 1.145190e+08    1
# 6.451395e+07    1
# 1.330467e+10    1
# 2.607670e+09    1
# 2.642132e+09    1
# Name: Circulating Supply, Length: 984, dtype: int64

# %%
df_log.describe()
# Out:
#         Market Cap        Price  Circulating Supply  Volume(24h)         % 1h  \
# count  1000.000000  1000.000000         1000.000000  1000.000000  1000.000000
# mean     18.542857    -0.458149           19.001000    15.653130    -0.000101
# std       1.710884     3.559171            3.480902     3.151045     0.021805
# min      16.449244   -18.112461            5.710427     2.197225    -0.099000
# 25%      17.161841    -2.245498           17.232077    14.055127    -0.006600
# 50%      18.234713    -0.314231           18.825182    15.730256    -0.001250
# 75%      19.426111     1.430311           20.722485    17.714204     0.004525
# max      27.517523    11.418418           35.407653    25.694468     0.159500
#
#              % 24h         % 7d
# count  1000.000000  1000.000000
# mean     -0.178689    -0.144834
# std       0.106516     0.271227
# min      -0.465200    -0.898200
# 25%      -0.242225    -0.266525
# 50%      -0.192100    -0.178650
# 75%      -0.138450    -0.072325
# ...

# %%
import statsmodels.api as sm
#Analysis
x = df_log.drop(columns = ['Price', 'Symbol', 'Market Cap', '% 1h'])
x = sm.add_constant(x)
y = df_log['Price']


model = sm.OLS(y, x, data = df_log)
crypto_model = model.fit()
crypto_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.868
# Model:                            OLS   Adj. R-squared:                  0.868
# Method:                 Least Squares   F-statistic:                     1636.
# Date:                Sun, 12 Dec 2021   Prob (F-statistic):               0.00
# Time:                        11:04:27   Log-Likelihood:                -1675.3
# No. Observations:                1000   AIC:                             3361.
# Df Residuals:                     995   BIC:                             3385.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm

#Cook'D for Outliers
influence = crypto_model.get_influence()
influence_frame = influence.summary_frame().reset_index()

sns.barplot(y = 'cooks_d',
            x = influence_frame.index,
           data = influence_frame)
# Out:
# <AxesSubplot:ylabel='cooks_d'>

# %%
max_index = influence_frame['cooks_d'].idxmax()
df_log.iloc[max_index]
# Out:
# Symbol                      GXC
# Market Cap            19.149527
# Price                  1.015231
# Circulating Supply    18.132999
# Volume(24h)           20.048887
# % 1h                     0.0151
# % 24h                   -0.4106
# % 7d                     3.7169
# Name: 303, dtype: object

# %%
#vif
from statsmodels.stats.outliers_influence import variance_inflation_factor

x = df_log.drop(columns = ['Price', 'Symbol'])
x = sm.add_constant(x)
y = df_log['Price']


model = sm.OLS(y, x, data = df_log)
crypto_model = model.fit()
crypto_model.summary()

vif = pd.DataFrame()
vif['variables'] = x.columns
vif['vif'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif

#collinarity is okay
# Out:
#             variables         vif
# 0               const  138.965646
# 1          Market Cap    1.751267
# 2  Circulating Supply    1.048947
# 3         Volume(24h)    1.854572
# 4                % 1h    1.022121
# 5               % 24h    1.362580
# 6                % 7d    1.252415

# %%
#non-normality
df_log['predict']= crypto_model.predict(x)
df_log['resid'] = df_log['Price']-df_log['predict']
with sns.axes_style('white'):
    plot=df_log.plot(kind='scatter',
                    x='predict', y = 'resid', alpha = 0.2, figsize=(10,6))

# %%
from scipy import stats
import matplotlib.pyplot as plt
stats.probplot(df_log['resid'], dist = 'norm', plot = plt)
plt.title('Normal Q-Q plot')
plt.show()
