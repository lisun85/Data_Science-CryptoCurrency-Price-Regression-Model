# %%
import requests
from bs4 import BeautifulSoup

r = requests.get('https://coinmarketcap.com/all/views/all/')
soup = BeautifulSoup(r.text, 'lxml')

data = []
table = soup.find('table')
for row in table.find_all('tr'):
    try:
        symbol = row.find('td', class_='cmc-table__column-name--symbol cmc-link').text
    except AttributeError:
        continue

    data.append((symbol))

for item in data:
    print(item)

# %%
import time
from selenium import webdriver

driver = webdriver.Chrome()
driver.get(('http://sdsclub.com'))
time.sleep(5)

driver.find_element_byxpath("/html/body/header/div/div/div[2]/a").click()
# Out:
# --------------------------------------------------------------------------
# AttributeError                           Traceback (most recent call last)
# <ipython-input-41-3e1d26d5d5a3> in <module>
#       6 time.sleep(5)
#       7
# ----> 8 driver.find_element_byxpath("/html/body/header/div/div/div[2]/a").click()
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_byxpath'

# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

driver = webdriver.Chrome()
driver.get('http://sdsclub.com')
time.sleep(5)



#links

button_one = driver.find_element_by_xpath('//*[@id="menu-item-456"]/a').click()
time.sleep(5)
button_one = driver.find_element_by_xpath('//*[@id="category-career"]/div/div[2]/div[4]/div/figure/a/img').click()
time.sleep(10)

button_close = driver.find_element_by_class_name('close-icon').click()

time.sleep(5)

#add parser
page_source = driver.page_source
soup = BeautifulSoup(page_source, 'lxml')

#add scrape info
scrape_one = [i.text for i in soup.findAll('span', {'class': 'desc'})]
df = pd.DataFrame(scrape_one)

# %%
df
# Out:
#                     0
# 0           8 Courses
# 1  92  Hours in Total
# 2     10 Case Studies

# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

driver = webdriver.Chrome()
driver.get('http://sdsclub.com')
time.sleep(5)



#links

button_one = driver.find_element_by_xpath('//*[@id="menu-item-456"]/a').click()
time.sleep(5)
button_one = driver.find_element_by_xpath('//*[@id="category-career"]/div/div[2]/div[4]/div/figure/a/img').click()
time.sleep(10)

button_close = driver.find_element_by_class_name('close-icon').click()

time.sleep(5)

#add parser
page_source = driver.page_source
soup = BeautifulSoup(page_source, 'lxml')

#add scrape info
scrape_one = [i.text for i in soup.findAll('span', {'class': 'desc'})]
scrape_two = [i.text for i in soup.findAll('div', {'class': 'single-path-article-content'})]
scrape_three = [i.text for i in soup.findAll('p', {'class': 'name'})]

df = pd.DataFrame(scrape_one)
df_two = pd.DataFrame(scrape_one)
df_three = pd.DataFrame(scrape_one)

print(df, df_two, df_three)

time.sleep(3)

driver.quit()
# Out:
#                     0
# 0           8 Courses
# 1  92  Hours in Total
# 2     10 Case Studies                     0
# 0           8 Courses
# 1  92  Hours in Total
# 2     10 Case Studies                     0
# 0           8 Courses
# 1  92  Hours in Total
# 2     10 Case Studies

# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

driver = webdriver.Chrome()
driver.get('http://sdsclub.com')
time.sleep(5)



#links

button_one = driver.find_element_by_xpath('//*[@id="menu-item-456"]/a').click()
time.sleep(5)
button_one = driver.find_element_by_xpath('//*[@id="category-career"]/div/div[2]/div[4]/div/figure/a/img').click()
time.sleep(10)

button_close = driver.find_element_by_class_name('close-icon').click()

time.sleep(5)

#add parser
page_source = driver.page_source
soup = BeautifulSoup(page_source, 'lxml')

#add scrape info
scrape_one = [i.text for i in soup.findAll('span', {'class': 'desc'})]
scrape_two = [i.text for i in soup.findAll('div', {'class': 'single-path-article-content'})]
scrape_three = [i.text for i in soup.findAll('p', {'class': 'name'})]

df = pd.DataFrame(scrape_one)
df_two = pd.DataFrame(scrape_two)
df_three = pd.DataFrame(scrape_three)

time.sleep(3)

driver.quit()

df_clean = df.replace('\n', " ", )
df_two_clean = df_two.replace('\n', " ", )
df_three_clean = df_three.replace('\n', " ", )
clean_stack = pd.concat([df_clean, df_two_clean, df_three_clean], axis = 1)

clean_stack
# Out:
#                     0                                                  0  \
# 0           8 Courses  Since several industries around the world use ...
# 1  92  Hours in Total  An AI engineer’s average annual salary is $111...
# 2     10 Case Studies           Basic programming knowledge - Python. \n
# 3                 NaN  \n\n\n\n \n\n\nKirill Eremenko\nData Scientist...
#
#                      0
# 0      Kirill Eremenko
# 1  Hadelin de Ponteves
# 2                  NaN
# 3                  NaN

# %%
# for real on CMC
