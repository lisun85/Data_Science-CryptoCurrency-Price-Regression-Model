# %%
#Trial 4 - 54 data sets, scroll and scrape method
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get('https://coinmarketcap.com/all/views/all/')
time.sleep(1)

#for i in range(1,21):
    #ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    #print(ticker)


#Next page
driver.execute_script("return document.body.scrollHeight")
driver.execute_script("window.scrollTo(0,1500)")
#1000 - HNT
#1500 - ONE


for i in range(1,54):
    ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    print(ticker)
# Out:
# BTC
# ETH
# BNB
# USDT
# SOL
# ADA
# XRP
# DOT
# USDC
# DOGE
# AVAX
# SHIB
# CRO
# LUNA
# LTC
# WBTC
# UNI
# BUSD
# LINK
# MATIC
# ALGO
# BCH
# EGLD
# AXS
# XLM
# VET
# MANA
# ICP
# UST
# TRX
# FTT
# ATOM
# THETA
# DAI
# FIL
# ETC
# BTCB
# FTM
# NEAR
# HBAR
# SAND
# HNT
# XTZ
# XMR
# LRC
# GRT
# EOS
# FLOW
# MIOTA
# KLAY
# CAKE
# AAVE
# ONE

# %%
#Trial 5 - 65 data sets, scroll and scrape method
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get('https://coinmarketcap.com/all/views/all/')
time.sleep(1)

#for i in range(1,21):
    #ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    #print(ticker)


#Next page
driver.execute_script("window.scrollTo(0,1500)")
#1000 - HNT
#1500 - ONE


for i in range(1,54):
    ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    print(ticker)
#Next page
time.sleep(3)
driver.execute_script("window.scrollTo(1500,3000)")
#2000 - HNT


for i in range(55,65):
    ticker2 = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    print(ticker2)
    
#note to Julia, I can only run this successfully once on the first call, I don't know why each subsequent call will break.
# Out:
# BTC
# ETH
# BNB
# USDT
# SOL
# ADA
# XRP
# DOT
# USDC
# DOGE
# AVAX
# SHIB
# CRO
# LUNA
# LTC
# WBTC
# UNI
# BUSD
# LINK
# MATIC
# ALGO
# BCH
# EGLD
# AXS
# XLM
# VET
# MANA
# ICP
# UST
# TRX
# FTT
# ATOM
# THETA
# DAI
# FIL
# ETC
# BTCB
# FTM
# NEAR
# HBAR
# SAND
# HNT
# XTZ
# XMR
# LRC
# GRT
# EOS
# FLOW
# MIOTA
# KLAY
# CAKE
# AAVE
# ONE
# ZEC
# LEO
# XEC
# MKR
# GALA
# BSV
# KSM
# NEO
# RUNE
# QNT

# %%
#Trial 6 - using while method to scroll all the way down, failed, stuck on forever while loop
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get('https://coinmarketcap.com/all/views/all/')
time.sleep(1)

#for i in range(1,21):
    #ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    #print(ticker)


#Next page
#driver.execute_script("window.scrollTo(0,1500)")
#1000 - HNT
#1500 - ONE




driver.execute_script('return document.body.scrollHeight')

while True:
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')


for i in range(1,54):
    ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    print(ticker)
# Out:
# --------------------------------------------------------------------------
# KeyboardInterrupt                        Traceback (most recent call last)
# <ipython-input-10-702a68ce3db5> in <module>
#      25
#      26 while True:
# ---> 27     driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
#      28
#      29
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     632             command = Command.EXECUTE_SCRIPT
#     633
# --> 634         return self.execute(command, {
#     635             'script': script,
#     636             'args': converted_args})['value']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     373             response = conn.urlopen(method, url, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#     377         redirect_location = redirect and response.get_redirect_location()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#Trial 7 - Load x4 times, Manually scroll through entirely to bottom, then scrape, WORKED!!!!!
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get('https://coinmarketcap.com/all/views/all/')
time.sleep(1)

#for i in range(1,21):
    #ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    #print(ticker)

#1000 - HNT
#1500 - ONE
#2000 - HNT

#Next page
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
load_more = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[3]/button').click()
time.sleep(3)
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
load_more = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[3]/button').click()
time.sleep(3)
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
load_more = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[3]/button').click()
time.sleep(3)
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
load_more = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[3]/button').click()
time.sleep(3)

#driver.execute_script('return document.body.scrollHeight')

driver.execute_script("window.scrollTo(0,1500)")
time.sleep(1)
driver.execute_script("window.scrollTo(1500,3000)")
time.sleep(1)
driver.execute_script("window.scrollTo(3000,4500)")
time.sleep(1)
driver.execute_script("window.scrollTo(4500,6000)")
time.sleep(1)
driver.execute_script("window.scrollTo(6000,7500)")
time.sleep(1)
driver.execute_script("window.scrollTo(7500,9000)")
time.sleep(1)
driver.execute_script("window.scrollTo(9000,10500)")
time.sleep(1)
driver.execute_script("window.scrollTo(10500,12000)")
time.sleep(1)
driver.execute_script("window.scrollTo(12000,13500)")
time.sleep(1)
driver.execute_script("window.scrollTo(13500,15000)")
time.sleep(1)
driver.execute_script("window.scrollTo(15000,16500)")
time.sleep(1)
driver.execute_script("window.scrollTo(16500,18000)")
time.sleep(1)
driver.execute_script("window.scrollTo(18000,19500)")
time.sleep(1)
driver.execute_script("window.scrollTo(19500,21000)")
time.sleep(1)
driver.execute_script("window.scrollTo(21000,22500)")
time.sleep(1)
driver.execute_script("window.scrollTo(22500,24000)")
time.sleep(1)
driver.execute_script("window.scrollTo(24000,25500)")
time.sleep(1)
driver.execute_script("window.scrollTo(25500,27000)")
time.sleep(1)
driver.execute_script("window.scrollTo(27000,28500)")
time.sleep(1)
driver.execute_script("window.scrollTo(28500,30000)")
time.sleep(1)
driver.execute_script("window.scrollTo(30000,31500)")
time.sleep(1)
driver.execute_script("window.scrollTo(31500,33000)")
time.sleep(1)
driver.execute_script("window.scrollTo(33000,34500)")
time.sleep(1)
driver.execute_script("window.scrollTo(34500,36000)")
time.sleep(1)
driver.execute_script("window.scrollTo(36000,37500)")
time.sleep(1)
driver.execute_script("window.scrollTo(37500,39000)")
time.sleep(1)
driver.execute_script("window.scrollTo(39000,40500)")
time.sleep(1)
driver.execute_script("window.scrollTo(40500,42000)")
time.sleep(1)
driver.execute_script("window.scrollTo(42000,43500)")
time.sleep(1)
driver.execute_script("window.scrollTo(43500,45000)")
time.sleep(1)
driver.execute_script("window.scrollTo(45000,45253)")

symbol = []
market_cap = []
price = []
circulation = []
volume = []
one_hour = []
twenty_four = []
seven_day = []

for i in range(1, 1001):
    ticker = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[3]/div').text;
    symbol.append(ticker)
    marketCap = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[4]/p/span[2]').text;
    market_cap.append(marketCap)
    price_= driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[5]/div/a/span').text;
    price.append(price_)
    circulation_ = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[6]/div').text;
    circulation.append(circulation_)
    volume_ = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[7]/a').text;
    volume.append(volume_)
    oneHour = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[8]/div').text;
    one_hour.append(oneHour)
    twentyFourHours = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[9]/div').text;
    twenty_four.append(twentyFourHours)
    sevenDays = driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[2]/div/div[1]/div/div[2]/div[3]/div/table/tbody/tr['+str(i)+']/td[10]/div').text;
    seven_day.append(sevenDays)

# %%
#total page lenght is 45253

#test the last dataset to see if above scraping was successful
seven_day
# Out:
# ['-5.26%',
#  '1.65%',
#  '2.90%',
#  '-0.08%',
#  '2.00%',
#  '-8.30%',
#  '-3.85%',
#  '-1.18%',
#  '0.12%',
#  '-5.98%',
#  '25.09%',
#  '100.35%',
#  '-17.97%',
#  '-3.16%',
#  '-6.13%',
#  '-5.88%',
#  '1.17%',
#  '-0.02%',
#  '-8.12%',
#  '10.51%',
#  '9.53%',
#  '-3.86%',
#  '57.26%',
#  '40.72%',
#  '-0.59%',
#  '-0.35%',
#  '-11.00%',
#  '-2.73%',
#  '-0.39%',
#  '-8.26%',
#  '-1.24%',
#  '10.43%',
#  '6.84%',
#  '0.62%',
#  '-8.13%',
#  '-3.24%',
#  '116.40%',
#  '-5.40%',
#  '3.46%',
#  '-10.32%',
#  '2.01%',
#  '1.07%',
#  '4.03%',
#  '-2.04%',
#  '-3.11%',
#  '12.98%',
#  '-2.88%',
#  '4.54%',
#  '9.76%',
#  '-1.01%',
#  '-9.72%',
#  '45.21%',
#  '-4.41%',
#  '27.22%',
#  '61.27%',
#  '7.27%',
#  '177.83%',
#  '-7.43%',
#  '12.31%',
#  '-4.95%',
#  '-5.79%',
#  '5.41%',
#  '-7.85%',
#  '-6.18%',
#  '-10.66%',
#  '23.62%',
#  '-6.72%',
#  '-12.69%',
#  '8.90%',
#  '-3.13%',
#  '-7.85%',
#  '22.31%',
#  '3.16%',
#  '-0.68%',
#  '6.76%',
#  '3.43%',
#  '-9.77%',
#  '-10.37%',
#  '3.13%',
#  '-6.07%',
#  '50.74%',
#  '-4.87%',
#  '-7.75%',
#  '-16.46%',
#  '0.41%',
#  '0.71%',
#  '-1.07%',
#  '102.76%',
#  '-3.27%',
#  '29.65%',
#  '43.39%',
#  '-7.94%',
#  '0.22%',
#  '21.93%',
#  '-0.01%',
#  '-14.40%',
#  '60.88%',
#  '1.64%',
#  '2.34%',
#  '-10.01%',
#  '0.57%',
#  '-4.53%',
#  '-16.36%',
#  '0.63%',
#  '-16.99%',
#  '-1.06%',
#  '-3.62%',
#  '-6.30%',
#  '4.43%',
#  '-4.32%',
#  '-3.94%',
#  '-0.06%',
#  '-4.76%',
#  '-1.17%',
#  '9.21%',
#  '-1.28%',
#  '17.75%',
#  '-24.77%',
#  '-9.29%',
#  '6.57%',
#  '13.49%',
#  '-1.36%',
#  '20.59%',
#  '-3.49%',
#  '28.10%',
#  '3.66%',
#  '100.35%',
#  '-0.96%',
#  '-7.48%',
#  '-6.77%',
#  '-6.23%',
#  '4.48%',
#  '27.67%',
#  '-4.23%',
#  '7.21%',
#  '5.96%',
#  '4.32%',
#  '0.00%',
#  '-9.54%',
#  '-16.86%',
#  '51.80%',
#  '23.17%',
#  '1.24%',
#  '8.65%',
#  '-3.17%',
#  '3.85%',
#  '96.05%',
#  '8.20%',
#  '36.82%',
#  '18.68%',
#  '-3.90%',
#  '-7.32%',
#  '-0.34%',
#  '-8.34%',
#  '38.16%',
#  '2.37%',
#  '2.19%',
#  '-2.53%',
#  '1.23%',
#  '-4.70%',
#  '0.18%',
#  '0.41%',
#  '0.26%',
#  '-10.13%',
#  '10.41%',
#  '-8.82%',
#  '-3.40%',
#  '-7.04%',
#  '2.81%',
#  '8.33%',
#  '0.89%',
#  '-12.35%',
#  '-5.44%',
#  '32.39%',
#  '-7.73%',
#  '2.21%',
#  '-7.46%',
#  '7.38%',
#  '-0.79%',
#  '-9.71%',
#  '11.30%',
#  '14.38%',
#  '0.10%',
#  '2.12%',
#  '2.10%',
#  '-5.30%',
#  '-3.27%',
#  '-0.06%',
#  '4.34%',
#  '-0.92%',
#  '-2.21%',
#  '-4.65%',
#  '0.02%',
#  '7.70%',
#  '27.41%',
#  '15.05%',
#  '-5.40%',
#  '-1.23%',
#  '39.77%',
#  '-0.51%',
#  '-14.11%',
#  '> 9000%',
#  '1.54%',
#  '2.31%',
#  '56.29%',
#  '-5.15%',
#  '6.31%',
#  '> 9000%',
#  '72.58%',
#  '-3.28%',
#  '9.92%',
#  '0.73%',
#  '-18.09%',
#  '-11.41%',
#  '44.22%',
#  '0.13%',
#  '-0.50%',
#  '-3.72%',
#  '2.73%',
#  '-2.88%',
#  '5.78%',
#  '-6.45%',
#  '-12.19%',
#  '33.85%',
#  '39.96%',
#  '-4.10%',
#  '38.24%',
#  '3.83%',
#  '-51.75%',
#  '-1.43%',
#  '0.94%',
#  '21.85%',
#  '0.17%',
#  '-14.11%',
#  '-1.53%',
#  '27.56%',
#  '44.44%',
#  '0.77%',
#  '72.14%',
#  '46.14%',
#  '34.97%',
#  '1.83%',
#  '0.91%',
#  '3.05%',
#  '14.74%',
#  '85.20%',
#  '94.17%',
#  '-13.66%',
#  '22.13%',
#  '-1.15%',
#  '0.58%',
#  '9.29%',
#  '-6.71%',
#  '-5.97%',
#  '15.68%',
#  '84.53%',
#  '23.72%',
#  '87.26%',
#  '22.57%',
#  '1.17%',
#  '0.97%',
#  '-1.95%',
#  '23.07%',
#  '54.69%',
#  '2.10%',
#  '24.71%',
#  '-6.53%',
#  '8.79%',
#  '-12.61%',
#  '65.94%',
#  '-4.26%',
#  '75.57%',
#  '-8.98%',
#  '30.29%',
#  '3.05%',
#  '-6.68%',
#  '0.17%',
#  '-14.76%',
#  '47.75%',
#  '144.13%',
#  '-5.98%',
#  '-14.34%',
#  '8.95%',
#  '38.39%',
#  '8.14%',
#  '198.82%',
#  '9.43%',
#  '14.67%',
#  '-8.86%',
#  '-35.50%',
#  '17.84%',
#  '-7.81%',
#  '-7.63%',
#  '-4.39%',
#  '65.82%',
#  '8.78%',
#  '-5.69%',
#  '-3.54%',
#  '4.26%',
#  '-5.30%',
#  '-9.23%',
#  '-10.71%',
#  '-2.13%',
#  '59.22%',
#  '-17.27%',
#  '-0.97%',
#  '-19.33%',
#  '-3.56%',
#  '20.71%',
#  '6.70%',
#  '14.99%',
#  '19.30%',
#  '0.95%',
#  '3.04%',
#  '-5.49%',
#  '-0.61%',
#  '-4.45%',
#  '-1.90%',
#  '7.78%',
#  '-11.76%',
#  '-2.93%',
#  '27.77%',
#  '36.78%',
#  '77.58%',
#  '16.54%',
#  '-0.80%',
#  '5.42%',
#  '5.89%',
#  '-0.66%',
#  '4.32%',
#  '-1.60%',
#  '10.61%',
#  '7.78%',
#  '-5.42%',
#  '6.71%',
#  '0.42%',
#  '29.61%',
#  '0.85%',
#  '-5.34%',
#  '21.72%',
#  '-0.92%',
#  '-4.75%',
#  '-4.73%',
#  '-18.89%',
#  '-13.44%',
#  '0.27%',
#  '-3.65%',
#  '-12.13%',
#  '546.11%',
#  '58.24%',
#  '2.69%',
#  '20.35%',
#  '-11.14%',
#  '3.31%',
#  '-0.69%',
#  '6.20%',
#  '1.27%',
#  '6.68%',
#  '23.14%',
#  '2.36%',
#  '160.29%',
#  '23.04%',
#  '9.19%',
#  '-1.51%',
#  '-4.16%',
#  '-3.49%',
#  '1.41%',
#  '-11.61%',
#  '-12.05%',
#  '3.71%',
#  '18.33%',
#  '-0.52%',
#  '183.63%',
#  '50.97%',
#  '-0.06%',
#  '-20.99%',
#  '-5.86%',
#  '9.95%',
#  '-6.90%',
#  '-7.95%',
#  '5.87%',
#  '71.76%',
#  '7.82%',
#  '-0.24%',
#  '59.44%',
#  '0.23%',
#  '42.97%',
#  '-30.92%',
#  '-3.56%',
#  '-0.85%',
#  '-8.70%',
#  '4.56%',
#  '1.86%',
#  '21.49%',
#  '-9.54%',
#  '-1.88%',
#  '258.22%',
#  '2.57%',
#  '-15.06%',
#  '0.02%',
#  '-8.97%',
#  '-14.64%',
#  '6.15%',
#  '-3.84%',
#  '0.96%',
#  '17.95%',
#  '-6.76%',
#  '-12.21%',
#  '13.62%',
#  '13.80%',
#  '-0.06%',
#  '-9.58%',
#  '1.90%',
#  '29.96%',
#  '16.52%',
#  '-1.39%',
#  '2.72%',
#  '3.65%',
#  '2.55%',
#  '35.15%',
#  '-6.61%',
#  '-2.38%',
#  '19.98%',
#  '0.22%',
#  '-20.61%',
#  '-37.38%',
#  '-0.14%',
#  '-19.52%',
#  '1.75%',
#  '12.04%',
#  '-7.19%',
#  '4.96%',
#  '9.03%',
#  '0.12%',
#  '5.52%',
#  '49.68%',
#  '20.35%',
#  '34.14%',
#  '3.18%',
#  '2.54%',
#  '-3.46%',
#  '-4.85%',
#  '-0.76%',
#  '1.73%',
#  '7.11%',
#  '-2.05%',
#  '0.36%',
#  '34.23%',
#  '7.70%',
#  '9.66%',
#  '-4.38%',
#  '1.39%',
#  '0.12%',
#  '-1.94%',
#  '0.54%',
#  '15.90%',
#  '2.23%',
#  '8.98%',
#  '-26.54%',
#  '10.46%',
#  '-1.27%',
#  '0.25%',
#  '-20.85%',
#  '9.03%',
#  '-14.14%',
#  '5.21%',
#  '3.78%',
#  '139.35%',
#  '-3.43%',
#  '0.89%',
#  '-4.07%',
#  '97.54%',
#  '1.36%',
#  '0.81%',
#  '-14.98%',
#  '-1.83%',
#  '-11.36%',
#  '-16.56%',
#  '-1.44%',
#  '0.18%',
#  '-0.36%',
#  '1.84%',
#  '-0.22%',
#  '-5.82%',
#  '7.07%',
#  '-5.21%',
#  '-16.98%',
#  '5.96%',
#  '-7.29%',
#  '12.44%',
#  '-1.96%',
#  '1.80%',
#  '-10.84%',
#  '63.75%',
#  '2.62%',
#  '5.13%',
#  '-5.73%',
#  '-11.22%',
#  '2.91%',
#  '41.16%',
#  '2.33%',
#  '> 9000%',
#  '33.44%',
#  '141.00%',
#  '38.98%',
#  '-2.23%',
#  '-17.90%',
#  '45.36%',
#  '17.45%',
#  '3.76%',
#  '1.00%',
#  '-1.08%',
#  '-14.48%',
#  '-3.86%',
#  '-8.64%',
#  '14.71%',
#  '5.79%',
#  '18.83%',
#  '13.56%',
#  '8.78%',
#  '0.16%',
#  '77.41%',
#  '-6.32%',
#  '-16.70%',
#  '9.44%',
#  '55.33%',
#  '4.17%',
#  '-12.43%',
#  '17.25%',
#  '13.34%',
#  '-3.72%',
#  '-14.22%',
#  '38.52%',
#  '-4.92%',
#  '12.04%',
#  '-8.24%',
#  '-14.97%',
#  '74.21%',
#  '6.33%',
#  '-5.81%',
#  '20.28%',
#  '7.46%',
#  '-10.67%',
#  '-6.31%',
#  '3.37%',
#  '11.99%',
#  '1.12%',
#  '1.78%',
#  '-48.08%',
#  '0.60%',
#  '31.74%',
#  '-4.56%',
#  '8.23%',
#  '-8.58%',
#  '-10.58%',
#  '-8.48%',
#  '7.46%',
#  '22.05%',
#  '6.63%',
#  '13.50%',
#  '-10.44%',
#  '-11.92%',
#  '7.35%',
#  '-16.13%',
#  '-0.43%',
#  '30.94%',
#  '0.75%',
#  '-3.29%',
#  '12.09%',
#  '0.77%',
#  '-5.36%',
#  '0.96%',
#  '35.43%',
#  '7.25%',
#  '-8.54%',
#  '12.28%',
#  '5.04%',
#  '29.63%',
#  '3.35%',
#  '6.53%',
#  '21.25%',
#  '-3.97%',
#  '11.19%',
#  '15.18%',
#  '-4.51%',
#  '-8.55%',
#  '0.40%',
#  '-14.77%',
#  '0.07%',
#  '1.53%',
#  '-3.86%',
#  '16.27%',
#  '72.38%',
#  '11.38%',
#  '28.24%',
#  '11.97%',
#  '-9.64%',
#  '5.60%',
#  '7.99%',
#  '75.79%',
#  '-2.87%',
#  '-14.98%',
#  '13.27%',
#  '0.66%',
#  '-30.56%',
#  '-11.84%',
#  '2.98%',
#  '16.87%',
#  '0.18%',
#  '4.56%',
#  '30.87%',
#  '171.08%',
#  '-7.66%',
#  '0.89%',
#  '0.08%',
#  '-3.10%',
#  '-11.22%',
#  '22.40%',
#  '1.31%',
#  '10.70%',
#  '-13.07%',
#  '4.55%',
#  '-4.62%',
#  '36.55%',
#  '-20.95%',
#  '-3.88%',
#  '-38.44%',
#  '-0.48%',
#  '-2.92%',
#  '15.31%',
#  '41.87%',
#  '-14.14%',
#  '-2.92%',
#  '95.65%',
#  '7.70%',
#  '-2.88%',
#  '-13.01%',
#  '5.26%',
#  '24.09%',
#  '1.88%',
#  '2.13%',
#  '-15.61%',
#  '-13.17%',
#  '-8.99%',
#  '-7.01%',
#  '23.04%',
#  '0.46%',
#  '-14.78%',
#  '8.23%',
#  '-6.88%',
#  '29.85%',
#  '-10.67%',
#  '-8.92%',
#  '21.02%',
#  '-5.94%',
#  '20.84%',
#  '-6.01%',
#  '72.50%',
#  '30.77%',
#  '8.48%',
#  '16.44%',
#  '29.20%',
#  '12.13%',
#  '6.61%',
#  '29.69%',
#  '3.91%',
#  '23.75%',
#  '-22.36%',
#  '-16.16%',
#  '3.69%',
#  '3.93%',
#  '22.59%',
#  '54.83%',
#  '29.37%',
#  '9.48%',
#  '4.24%',
#  '2.80%',
#  '6.65%',
#  '-13.72%',
#  '-10.52%',
#  '19.68%',
#  '1.63%',
#  '1.11%',
#  '-11.44%',
#  '11.14%',
#  '-20.20%',
#  '1.62%',
#  '-8.93%',
#  '-15.86%',
#  '14.80%',
#  '21.29%',
#  '-19.90%',
#  '-15.31%',
#  '23.73%',
#  '-0.46%',
#  '8.36%',
#  '-10.44%',
#  '22.04%',
#  '-2.51%',
#  '-3.60%',
#  '-7.39%',
#  '-9.73%',
#  '-0.99%',
#  '14.26%',
#  '28.98%',
#  '-1.99%',
#  '-9.11%',
#  '-11.78%',
#  '23.30%',
#  '2.20%',
#  '20.62%',
#  '6.65%',
#  '7.58%',
#  '37.94%',
#  '-3.57%',
#  '53.09%',
#  '49.28%',
#  '11.25%',
#  '-2.18%',
#  '-9.62%',
#  '26.92%',
#  '163.68%',
#  '-0.82%',
#  '-14.50%',
#  '19.20%',
#  '28.76%',
#  '-55.20%',
#  '8.78%',
#  '-13.42%',
#  '-7.58%',
#  '57.20%',
#  '0.52%',
#  '-8.45%',
#  '0.20%',
#  '-9.93%',
#  '11.34%',
#  '-1.05%',
#  '2.51%',
#  '-4.28%',
#  '-30.83%',
#  '-0.20%',
#  '-10.25%',
#  '-4.96%',
#  '-1.97%',
#  '0.20%',
#  '46.58%',
#  '19.86%',
#  '-5.96%',
#  '8.04%',
#  '-7.33%',
#  '-1.22%',
#  '7.41%',
#  '19.46%',
#  '29.12%',
#  '-19.84%',
#  '36.89%',
#  '67.59%',
#  '13.86%',
#  '11.98%',
#  '3.02%',
#  '-15.44%',
#  '12.87%',
#  '-8.36%',
#  '-57.76%',
#  '5.92%',
#  '-7.58%',
#  '-3.28%',
#  '-4.89%',
#  '0.22%',
#  '7.97%',
#  '-6.86%',
#  '-1.75%',
#  '-11.85%',
#  '0.41%',
#  '8.04%',
#  '-6.14%',
#  '-13.12%',
#  '242.57%',
#  '0.80%',
#  '4.85%',
#  '43.46%',
#  '-34.73%',
#  '0.21%',
#  '-77.18%',
#  '-1.80%',
#  '45.66%',
#  '15.56%',
#  '-1.84%',
#  '-11.89%',
#  '-13.04%',
#  '-4.52%',
#  '-17.02%',
#  '34.43%',
#  '-9.62%',
#  '-13.04%',
#  '-36.68%',
#  '0.16%',
#  '8.66%',
#  '23.26%',
#  '0.76%',
#  '1.22%',
#  '2.75%',
#  '-0.63%',
#  '-3.21%',
#  '-2.33%',
#  '28.62%',
#  '-29.40%',
#  '0.02%',
#  '-29.86%',
#  '17.00%',
#  '-22.51%',
#  '-25.20%',
#  '3.25%',
#  '-8.45%',
#  '53.69%',
#  '38.53%',
#  '15.11%',
#  '7.80%',
#  '-3.57%',
#  '139.59%',
#  '25.02%',
#  '-8.37%',
#  '1.85%',
#  '-8.89%',
#  '-8.28%',
#  '-17.65%',
#  '8.18%',
#  '2.52%',
#  '66.04%',
#  '-7.18%',
#  '2.16%',
#  '-1.63%',
#  '-4.41%',
#  '-26.91%',
#  '-27.44%',
#  '-21.07%',
#  '-0.89%',
#  '26.33%',
#  '42.48%',
#  '-6.18%',
#  '6.08%',
#  '17.21%',
#  '-8.34%',
#  '15.65%',
#  '6.85%',
#  '34.71%',
#  '-8.92%',
#  '34.02%',
#  '44.07%',
#  '-13.13%',
#  '5.33%',
#  '-3.19%',
#  '35.80%',
#  '-6.41%',
#  '-9.26%',
#  '-3.02%',
#  '-7.33%',
#  '27.54%',
#  '-1.70%',
#  '0.94%',
#  '-6.99%',
#  '-6.86%',
#  '-9.76%',
#  '-23.46%',
#  '-26.57%',
#  '-21.67%',
#  '-13.12%',
#  '-26.76%',
#  '18.03%',
#  '0.79%',
#  '-3.44%',
#  '-8.16%',
#  '-5.80%',
#  '-31.92%',
#  '-9.98%',
#  '7.26%',
#  '9.21%',
#  '-1.21%',
#  '-14.70%',
#  '-1.44%',
#  '99.54%',
#  '13.37%',
#  '3.22%',
#  '-12.10%',
#  '-10.77%',
#  '76.28%',
#  '-5.41%',
#  '-9.71%',
#  '4.47%',
#  '26.15%',
#  '-24.71%',
#  '60.16%',
#  '-1.51%',
#  '-9.37%',
#  '-30.13%',
#  '-6.47%',
#  '75.33%',
#  '1.47%',
#  '72.83%',
#  '-5.23%',
#  '0.04%',
#  '-19.58%',
#  '-9.81%',
#  '9.36%',
#  '-5.41%',
#  '-19.59%',
#  '-17.72%',
#  '-3.69%',
#  '14.81%',
#  '23.73%',
#  '-9.68%',
#  '22.47%',
#  '6.29%',
#  '-21.50%',
#  '-26.68%',
#  '10.22%',
#  '126.73%',
#  '-1.62%',
#  '7.30%',
#  '-2.15%',
#  '-10.16%',
#  '-50.15%',
#  '3.89%',
#  '-26.46%',
#  '-10.26%',
#  '-0.22%',
#  '13.25%',
#  '-1.29%',
#  '1.56%',
#  '3.54%',
#  '44.28%',
#  '-14.12%',
#  '-1.10%',
#  '-1.79%',
#  '-17.12%',
#  '1.72%',
#  '2.62%',
#  '-1.63%',
#  '-1.81%',
#  '12.76%',
#  '-4.59%',
#  '-3.40%',
#  '-77.93%',
#  '-5.08%',
#  '-19.52%',
#  '12.56%',
#  '4.17%',
#  '-5.55%',
#  '-9.99%',
#  '21.91%',
#  '5.18%',
#  '25.11%',
#  '-4.70%',
#  '2.53%',
#  '-10.68%',
#  '-11.70%',
#  '2.62%',
#  '12.69%',
#  '6.82%',
#  '0.92%',
#  '-3.27%',
#  '-17.93%',
#  '-14.43%',
#  '15.52%',
#  '-15.02%',
#  '17.38%',
#  '-5.41%',
#  '23.55%',
#  '1.00%',
#  '18.39%',
#  '-5.97%',
#  '4.50%',
#  '5.77%',
#  '5.06%',
#  '2.74%',
#  '-17.91%',
#  '22.84%',
#  '34.82%',
#  '-4.17%',
#  '-2.91%',
#  '52.04%',
#  '47.23%',
#  '-0.34%',
#  '54.45%',
#  '142.80%',
#  '-8.14%',
#  '2.24%',
#  '-0.91%',
#  '34.18%',
#  '9.78%',
#  '-7.19%',
#  '15.95%',
#  '-18.27%',
#  '-9.50%',
#  '-14.00%',
#  '2.92%',
#  '-1.02%',
#  '-19.08%',
#  '26.08%',
#  '-1.27%']

# %%
#Combining all dataFrames
df1 = pd.DataFrame(symbol)
df2 = pd.DataFrame(market_cap)
df3 = pd.DataFrame(price)
df4 = pd.DataFrame(circulation) 
df5 = pd.DataFrame(volume) 
df6 = pd.DataFrame(one_hour) 
df7 = pd.DataFrame(twenty_four)
df8 = pd.DataFrame(seven_day)

stack = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8], axis = 1)
stack
# Out:
#         0                   0           0                      0  \
# 0     BTC  $1,065,099,089,665  $56,408.99         18,881,725 BTC
# 1     ETH    $501,356,078,211   $4,232.03        118,467,127 ETH
# 2     BNB     $96,840,382,324     $580.57      166,801,148 BNB *
# 3    USDT     $72,532,627,152       $1.00  72,495,543,702 USDT *
# 4     SOL     $65,690,772,617     $216.15      303,913,193 SOL *
# ..    ...                 ...         ...                    ...
# 995  SWOP         $16,748,121      $10.23       1,636,442 SWOP *
# 996   NGM         $16,672,817     $0.8438       19,760,286 NGM *
# 997   DON         $16,618,749     $0.5566       29,857,636 DON *
# 998   ANW         $16,540,250    $0.06008      275,297,977 ANW *
# 999  mUSO         $16,522,025      $57.11         289,320 mUSO *
#
#                    0       0       0        0
# 0    $35,934,560,996  -0.59%   0.02%   -5.26%
# 1    $21,468,490,510  -1.22%   2.13%    1.65%
# 2     $2,963,415,161  -0.65%   2.54%    2.90%
# 3    $85,183,639,282  -0.05%   0.01%   -0.08%
# 4     $2,356,135,861  -1.58%  -0.76%    2.00%
# ..               ...     ...     ...      ...
# 995          $73,119  -0.27%  -0.74%    2.92%
# 996         $371,883  -0.08%  10.06%   -1.02%
# 997         $434,742   1.92%   0.95%  -19.08%
# 998      $24,843,065  -1.56%  21.13%   26.08%
# 999         $172,972  -0.03%   4.14%   -1.27%
#
# [1000 rows x 8 columns]

# %%
#adding headers
stack.columns = ['Ticker', 'Market Cap', 'Price', 'Circulating Supply', 'Volume(24h)', '% 1h', '% 24h', '% 7']
stack
# Out:
#     Ticker          Market Cap       Price     Circulating Supply  \
# 0      BTC  $1,065,099,089,665  $56,408.99         18,881,725 BTC
# 1      ETH    $501,356,078,211   $4,232.03        118,467,127 ETH
# 2      BNB     $96,840,382,324     $580.57      166,801,148 BNB *
# 3     USDT     $72,532,627,152       $1.00  72,495,543,702 USDT *
# 4      SOL     $65,690,772,617     $216.15      303,913,193 SOL *
# ..     ...                 ...         ...                    ...
# 995   SWOP         $16,748,121      $10.23       1,636,442 SWOP *
# 996    NGM         $16,672,817     $0.8438       19,760,286 NGM *
# 997    DON         $16,618,749     $0.5566       29,857,636 DON *
# 998    ANW         $16,540,250    $0.06008      275,297,977 ANW *
# 999   mUSO         $16,522,025      $57.11         289,320 mUSO *
#
#          Volume(24h)    % 1h   % 24h      % 7
# 0    $35,934,560,996  -0.59%   0.02%   -5.26%
# 1    $21,468,490,510  -1.22%   2.13%    1.65%
# 2     $2,963,415,161  -0.65%   2.54%    2.90%
# 3    $85,183,639,282  -0.05%   0.01%   -0.08%
# 4     $2,356,135,861  -1.58%  -0.76%    2.00%
# ..               ...     ...     ...      ...
# 995          $73,119  -0.27%  -0.74%    2.92%
# 996         $371,883  -0.08%  10.06%   -1.02%
# 997         $434,742   1.92%   0.95%  -19.08%
# 998      $24,843,065  -1.56%  21.13%   26.08%
# 999         $172,972  -0.03%   4.14%   -1.27%
#
# [1000 rows x 8 columns]
